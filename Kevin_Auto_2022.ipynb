# %% [markdown]
# # <img src="IMG01.jpg"/>

# %% [markdown]
# <center><h1 Style="color:#00FFF"> Analísis de Datos </h1></center>
# <center><h5> Universidad Castro Carazo </h5></center>
# <center><h6> 3C - 2022 </h6></center>
# </br>
# <p Style = "text-align: justify"> fue presentado en el Salón del Automóvil de Ginebra de 2019 como el automóvil nuevo más caro de la historia, con un costo de 11 millones de €. Fue creado para celebrar los 110 años desde que Ettore Bugatti fundó la marca en 1909 </p>
#
# Como se puede incrementar las ventas de autos?
#
# Se debe de realizar un analisis del conjunto de datos facilitado por la empresa a efectos de poder brindar conocimiento sobre las distribucione de sus lotes de venta, los autos con mayor precio, o caracteristicas de los autos.</p>
# </br>
# <a href="https://archive.ics.uci.edu/m1/datasets/automobile"> Fuente de datos para el el proceso de analisis </a>

# %% [markdown]
# <h2 Style="color:#1E90FF">1. Carga y estandarizacion de los set de datos</h2>
#
#
#
# <p>Que se hace en esta etapa?</p>
#
#
#
# <ol>
#     <li>Importar las librerias de necesarias</li>
#     <li>Importar el o los set de datos</li>
#     <li>Revisar los ecabezados de los DataFrames</li>
#     <li>Si solo Si temenos mas de 1 set de datos - Unir los set de datos en un unico Dataframe</li>
# </ol>
#
#
#
# <h3 Style="color:#2F4F4F">1.1 Importar las librerias</h3>

# %%
import pandas as pd     #Se usa paa elmanejo de ls Dataframe
import numpy as np      #Se usa para el manejo de las estructuras de datos (Array, Listas, Tuplas, Diccionarios)
import matplotlib.pyplot as plt     #Se usa para crear las graficas.

# %% [markdown]
# <h3 Style="color:#2F4F4F">1.2 Importar los Set de datos</h3>

# %%
cols = ["symboling", "normalized", "make", "fuel", "aspiration", "doors",
       "style", "wheels", "engine", "base", "length", "width", "heingt",
       "curb", "engineType", "Cylinders", "engine-size", "system", "bore", "stroke",
       "compression", "horsepower", "peak", "City", "Higway", "price"]

#df = Data Frame
df_1er_autos = pd.read_csv("autos.csv" , names=cols)
df_2do_autos = pd.read_csv("autos1.csv" , names=cols)

# %%
df_1er_autos.shape
# Out:
# (197, 26)

# %%
df_2do_autos.shape
# Out:
# (29, 26)

# %%
df_1er_autos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engine-size  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...          130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...          152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...          109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...          136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
# 4        115  5500   18     22  17450
#
# [5 rows x 26 columns]

# %%
df_1er_autos.tail(5)
# Out:
#      symboling normalized        make    fuel aspiration doors  style wheels  \
# 192          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 193          0          ?  volkswagen     gas        std  four  wagon    fwd
# 194         -2        103       volvo     gas        std  four  sedan    rwd
# 195         -1         74       volvo     gas        std  four  wagon    rwd
# 196         -2        103       volvo     gas        std  four  sedan    rwd
#
#     engine   base  ...  engine-size  system  bore  stroke compression  \
# 192  front  100.4  ...           97     idi  3.01    3.40        23.0
# 193  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 194  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 195  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 196  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#     horsepower  peak City Higway  price
# 192         68  4500   33     38  13845
# 193         88  5500   25     31  12290
# 194        114  5400   23     28  12940
# 195        114  5400   23     28  13415
# 196        114  5400   24     28  15985
#
# [5 rows x 26 columns]

# %%
df_2do_autos.tail(5)
# Out:
#     symboling normalized        make    fuel aspiration doors  style wheels  \
# 24          0          ?  volkswagen  diesel      turbo  four  sedan    fwd
# 25          0          ?  volkswagen     gas        std  four  wagon    fwd
# 26         -2        103       volvo     gas        std  four  sedan    rwd
# 27         -1         74       volvo     gas        std  four  wagon    rwd
# 28         -2        103       volvo     gas        std  four  sedan    rwd
#
#    engine   base  ...  engine-size  system  bore  stroke compression  \
# 24  front  100.4  ...           97     idi  3.01    3.40        23.0
# 25  front  100.4  ...          109    mpfi  3.19    3.40         9.0
# 26  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 27  front  104.3  ...          141    mpfi  3.78    3.15         9.5
# 28  front  104.3  ...          141    mpfi  3.78    3.15         9.5
#
#    horsepower  peak City  Higway  price
# 24         68  4500   33      38  13845
# 25         88  5500   25      31  12290
# 26        114  5400   23      28  12940
# 27        114  5400   23      28  13415
# 28        114  5400   24      28  15985
#
# [5 rows x 26 columns]

# %%
df_1er_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engine-size  compression        City      Higway
# count   197.000000   197.000000   197.000000  197.000000  197.000000
# mean   2534.796954   126.263959    10.128020   25.416244   30.984772
# std     520.401159    42.282594     3.934467    6.566717    6.908644
# min    1488.000000    61.000000     7.000000   13.000000   16.000000
# 25%    2140.000000    97.000000     8.600000   19.000000   25.000000
# 50%    2405.000000   110.000000     9.000000   25.000000   30.000000
# 75%    2844.000000   141.000000     9.400000   30.000000   36.000000
# max    4066.000000   326.000000    23.000000   49.000000   54.000000

# %% [markdown]
# <h5 Style="color: ·B0C4DE"> 1.31 Revisar los encabezados de los DataFrame </h5>
# <p> Se motiva la estandarizacion de los nombres de las columnas, considerando lo siguiente </p>
#
# <ol>
#     <li>Los nombres de las columnas no deben contener espacios en blanco</li>
#     <li>Los nombres no deben empeza por numeros</li>
#     <li>Si el nombre se conforma po 2 o mas palabras la letra inicial de cada palabra va en mayuscula.</li>
#     <li>No deben existir nombres repetidos</li>
# </ol>

# %%
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engine-size', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_1er_autos.rename({"engine-size" : "engineSize"}, axis=1, inplace=True)
df_2do_autos.rename({"engine-size" : "engineSize"}, axis=1, inplace=True)
df_1er_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engineSize', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %%
df_2do_autos.columns
# Out:
# Index(['symboling', 'normalized', 'make', 'fuel', 'aspiration', 'doors',
#        'style', 'wheels', 'engine', 'base', 'length', 'width', 'heingt',
#        'curb', 'engineType', 'Cylinders', 'engineSize', 'system', 'bore',
#        'stroke', 'compression', 'horsepower', 'peak', 'City', 'Higway',
#        'price'],
#       dtype='object')

# %% [markdown]
# <h5 Style="color:#1E90FF">1. Revision de variables</h5>
# <p>Se motiva la estandarizacion de los nombres de las columnas, considerando lo siguiente</p>
#
# <ol>
#     <li>los nombres de las columnas no deben contener espacios en blancos</li>
#     <li>Los nombres no deben de comenzar con numeros</li>
#     <li>Si el nombre se conforma por 2 o mas palabras la letra inicial de cada palabra va en mayuscula</li>
#     <li>No deben existir nombres repetidos</li>
# </ol>

# %% [markdown]
# <h5 Style="color:#1E90FF">1. Revision de variables</h5>
# <p>Este proceso de revision permite identificar variables o datos que deben ser analizados de manera independiente, porque no concuerda con la metadata</p>

# %%
df_1er_autos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  197.000000  197.000000  197.000000  197.000000  197.000000
# mean     0.913706   98.409645  173.450254   65.812690   53.628934
# std      1.202746    5.866965   12.213912    2.128306    2.438891
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.000000   52.000000
# 50%      1.000000   96.500000  172.600000   65.400000   53.900000
# 75%      2.000000  100.400000  178.500000   66.500000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engineSize  compression        City      Higway
# count   197.000000  197.000000   197.000000  197.000000  197.000000
# mean   2534.796954  126.263959    10.128020   25.416244   30.984772
# std     520.401159   42.282594     3.934467    6.566717    6.908644
# min    1488.000000   61.000000     7.000000   13.000000   16.000000
# 25%    2140.000000   97.000000     8.600000   19.000000   25.000000
# 50%    2405.000000  110.000000     9.000000   25.000000   30.000000
# 75%    2844.000000  141.000000     9.400000   30.000000   36.000000
# max    4066.000000  326.000000    23.000000   49.000000   54.000000

# %%
df_1er_autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symboling    197 non-null    int64
#  1   normalized   197 non-null    object
#  2   make         197 non-null    object
#  3   fuel         197 non-null    object
#  4   aspiration   197 non-null    object
#  5   doors        197 non-null    object
#  6   style        197 non-null    object
#  7   wheels       197 non-null    object
#  8   engine       197 non-null    object
#  9   base         197 non-null    float64
#  10  length       197 non-null    float64
#  11  width        197 non-null    float64
#  12  heingt       197 non-null    float64
#  13  curb         197 non-null    int64
#  14  engineType   197 non-null    object
#  15  Cylinders    197 non-null    object
#  16  engineSize   197 non-null    int64
#  17  system       197 non-null    object
#  18  bore         197 non-null    object
#  19  stroke       197 non-null    object
#  20  compression  197 non-null    float64
#  21  horsepower   197 non-null    object
#  22  peak         197 non-null    object
#  23  City         197 non-null    int64
#  24  Higway       197 non-null    int64
#  25  price        197 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 40.1+ KB

# %%
df_1er_autos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
# 4        115  5500   18     22  17450
#
# [5 rows x 26 columns]

# %%
temp = df_1er_autos.groupby(["style"]).count()
temp = temp.iloc[:,:1]
temp
# Out:
#              symboling
# style
# convertible          6
# hardtop              8
# hatchback           70
# sedan               90
# wagon               23

# %% [markdown]
# <h5 Style="color: #778899">1.4 Unir Set de Datos </h5>

# %%
unionArchivos = [df_1er_autos, df_2do_autos]
dfAutos = pd.concat(unionArchivos)
dfAutos.shape
# Out:
# (226, 26)

# %%
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3          ?  alfa-romero  gas        std   two  convertible
# 1          3          ?  alfa-romero  gas        std   two  convertible
# 2          1          ?  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front  88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front  94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front  99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front  99.4  ...         136    mpfi  3.19    3.40         8.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
# 4        115  5500   18     22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# <h2 style="color:#001283"> 2. Manejo de los valores faltantes o perdidos </h2>
#
# <p>Que se hace en este apartado </p>
#
# <ol>
#     <li>Identificar como se muestran los valores faltantes y los estandarizamos (NaN)</li>
#     <li>Contar la cantidad de valores faltantes por variable</li>
#     <li>Analisis de imputacion de valores numeros con la medida</li>
#     <li>Analisis de imputacion de valorescategoricos con el mas frecuente</li>
#     <li>Eliminar filas con valores faltantes</li>
# </ol>
#
# <h2 syle="color:#001283"> 2.1 Identificar como se muestran los valores faltantes y los estandarizamos (NaN) </h2>

# %%
dfAutos.replace("?", np.nan, inplace = True)
dfAutos.head(10)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        NaN  alfa-romero  gas        std   two  convertible
# 1          3        NaN  alfa-romero  gas        std   two  convertible
# 2          1        NaN  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
# 5          2        NaN         audi  gas        std   two        sedan
# 6          1        158         audi  gas        std  four        sedan
# 7          1        NaN         audi  gas        std  four        wagon
# 8          1        158         audi  gas      turbo  four        sedan
# 9          0        NaN         audi  gas      turbo   two    hatchback
#
#   wheels engine   base  ...  engineSize  system  bore  stroke compression  \
# 0    rwd  front   88.6  ...         130    mpfi  3.47    2.68         9.0
# 1    rwd  front   88.6  ...         130    mpfi  3.47    2.68         9.0
# 2    rwd  front   94.5  ...         152    mpfi  2.68    3.47         9.0
# 3    fwd  front   99.8  ...         109    mpfi  3.19    3.40        10.0
# 4    4wd  front   99.4  ...         136    mpfi  3.19    3.40         8.0
# 5    fwd  front   99.8  ...         136    mpfi  3.19    3.40         8.5
# 6    fwd  front  105.8  ...         136    mpfi  3.19    3.40         8.5
# 7    fwd  front  105.8  ...         136    mpfi  3.19    3.40         8.5
# 8    fwd  front  105.8  ...         131    mpfi  3.13    3.40         8.3
# 9    4wd  front   99.5  ...         131    mpfi  3.13    3.40         7.0
#
#   horsepower  peak City Higway  price
# 0        111  5000   21     27  13495
# 1        111  5000   21     27  16500
# 2        154  5000   19     26  16500
# 3        102  5500   24     30  13950
# 4        115  5500   18     22  17450
# 5        110  5500   19     25  15250
# 6        110  5500   19     25  17710
# 7        110  5500   19     25  18920
# 8        140  5500   17     20  23875
# 9        160  5500   16     22    NaN
#
# [10 rows x 26 columns]

# %% [markdown]
# <h2 style="color:#2082d8"> 2.2 Contar la cantidad de valores faltantes por variable </h2>

# %%
dfValoresFaltantes = dfAutos.isnull()
dfValoresFaltantes.head(5)
# Out:
#    symboling  normalized   make   fuel  aspiration  doors  style  wheels  \
# 0      False        True  False  False       False  False  False   False
# 1      False        True  False  False       False  False  False   False
# 2      False        True  False  False       False  False  False   False
# 3      False       False  False  False       False  False  False   False
# 4      False       False  False  False       False  False  False   False
#
#    engine   base  ...  engineSize  system   bore  stroke  compression  \
# 0   False  False  ...       False   False  False   False        False
# 1   False  False  ...       False   False  False   False        False
# 2   False  False  ...       False   False  False   False        False
# 3   False  False  ...       False   False  False   False        False
# 4   False  False  ...       False   False  False   False        False
#
#    horsepower   peak   City  Higway  price
# 0       False  False  False   False  False
# 1       False  False  False   False  False
# 2       False  False  False   False  False
# 3       False  False  False   False  False
# 4       False  False  False   False  False
#
# [5 rows x 26 columns]

# %%
for column in dfValoresFaltantes.columns.values.tolist():
    print(column)
    print(dfValoresFaltantes[column].value_counts())
    print("")
# Out:
# symboling
# False    226
# Name: symboling, dtype: int64
#
# normalized
# False    180
# True      46
# Name: normalized, dtype: int64
#
# make
# False    226
# Name: make, dtype: int64
#
# fuel
# False    226
# Name: fuel, dtype: int64
#
# aspiration
# False    226
# Name: aspiration, dtype: int64
#
# doors
# False    224
# True       2
# Name: doors, dtype: int64
#
# style
# False    226
# Name: style, dtype: int64
#
# wheels
# False    226
# Name: wheels, dtype: int64
#
# engine
# False    226
# Name: engine, dtype: int64
#
# base
# False    226
# Name: base, dtype: int64
#
# length
# False    226
# Name: length, dtype: int64
#
# width
# False    226
# Name: width, dtype: int64
#
# heingt
# False    226
# Name: heingt, dtype: int64
#
# curb
# False    226
# Name: curb, dtype: int64
#
# engineType
# False    226
# Name: engineType, dtype: int64
#
# Cylinders
# False    226
# Name: Cylinders, dtype: int64
#
# engineSize
# False    226
# Name: engineSize, dtype: int64
#
# system
# False    226
# Name: system, dtype: int64
#
# bore
# False    222
# True       4
# Name: bore, dtype: int64
#
# stroke
# False    222
# True       4
# Name: stroke, dtype: int64
#
# compression
# False    226
# Name: compression, dtype: int64
#
# horsepower
# False    224
# True       2
# Name: horsepower, dtype: int64
#
# peak
# False    224
# True       2
# Name: peak, dtype: int64
#
# City
# False    226
# Name: City, dtype: int64
#
# Higway
# False    226
# Name: Higway, dtype: int64
#
# price
# False    222
# True       4
# Name: price, dtype: int64

# %%
dfAutos.describe()
# Out:
#         symboling        base      length       width      heingt  \
# count  226.000000  226.000000  226.000000  226.000000  226.000000
# mean     0.902655   98.626991  173.929646   65.853982   53.728761
# std      1.271672    5.611570   11.744470    2.015475    2.365420
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  167.300000   64.200000   52.000000
# 50%      1.000000   97.250000  173.200000   65.500000   54.100000
# 75%      2.000000  101.800000  180.200000   66.500000   55.600000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               curb  engineSize  compression        City      Higway
# count   226.000000  226.000000   226.000000  226.000000  226.000000
# mean   2540.597345  126.486726    10.300973   25.477876   31.044248
# std     498.165891   40.340465     4.148393    6.384143    6.767096
# min    1488.000000   61.000000     7.000000   13.000000   16.000000
# 25%    2205.250000   98.000000     8.625000   20.000000   25.000000
# 50%    2414.000000  115.000000     9.000000   25.000000   30.000000
# 75%    2846.250000  146.000000     9.400000   30.000000   34.000000
# max    4066.000000  326.000000    23.000000   49.000000   54.000000

# %% [markdown]
# <h2 style="color:#2082d8"> 2.4 Analisis de imputacion de valores numeros con la media </h2>
# <img src="img02.png" alt="Valores Perdidos">

# %% [markdown]
# <h2 style="color:#2082d8"> 2.5 Analisis de imputacion de valores categoricos </h2>

# %%
mean_value = dfAutos["horsepower"].astype("float").mean(axis=0) # Obteniendo la medida de la variable 
print("La medida qqes: ", mean_value)
# Out:
# La medida qqes:  3.3201376146789

# %%
dfAutos["horsepower"].replace(np.nan, 102, inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    Higway  price City L/100km Higway L/100km
# 0      27  13495    11.190476       8.703704
# 1      27  16500    11.190476       8.703704
# 2      26  16500    12.368421       9.038462
# 3      30  13950     9.791667       7.833333
# 4      22  17450    13.055556      10.681818
#
# [5 rows x 28 columns]

# %% [markdown]
# <h2 style="color:#2082d8"> 2.5 Analisis de imputacion de valores categoricos con el mas frecuente </h2>

# %%
dfAutos["doors"].value_counts().idxmax()
"four"
# Out:
# 'four'

# %%
dfAutos["doors"].replace(np.nan, "four", inplace = True)
dfAutos.head(5)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
# 3          2        164         audi  gas        std  four        sedan
# 4          2        164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
# 3    fwd  front  99.8  ...  3.19    3.40         10.0         102  5500   24
# 4    4wd  front  99.4  ...  3.19    3.40          8.0         115  5500   18
#
#    Higway  price City L/100km Higway L/100km
# 0      27  13495    11.190476       8.703704
# 1      27  16500    11.190476       8.703704
# 2      26  16500    12.368421       9.038462
# 3      30  13950     9.791667       7.833333
# 4      22  17450    13.055556      10.681818
#
# [5 rows x 28 columns]

# %% [markdown]
# <h2 style="color:#2082d8"> 2.5 Eliminar filas con valores faltantes </h2>

# %%
dfAutos.dropna(subset = ["price"], axis = 0, inplace = True)
dfAutos.reset_index(drop=True, inplace = True)

# %%
dfValoresFaltantes = dfAutos.isnull()
dfValoresFaltantes.head(5)
for column in dfValoresFaltantes.columns.values.tolist():
    print(column)
    print(dfValoresFaltantes[column].value_counts())
    print("")
# Out:
# symboling
# False    222
# Name: symboling, dtype: int64
#
# normalized
# False    222
# Name: normalized, dtype: int64
#
# make
# False    222
# Name: make, dtype: int64
#
# fuel
# False    222
# Name: fuel, dtype: int64
#
# aspiration
# False    222
# Name: aspiration, dtype: int64
#
# doors
# False    222
# Name: doors, dtype: int64
#
# style
# False    222
# Name: style, dtype: int64
#
# wheels
# False    222
# Name: wheels, dtype: int64
#
# engine
# False    222
# Name: engine, dtype: int64
#
# base
# False    222
# Name: base, dtype: int64
#
# length
# False    222
# Name: length, dtype: int64
#
# width
# False    222
# Name: width, dtype: int64
#
# heingt
# False    222
# Name: heingt, dtype: int64
#
# curb
# False    222
# Name: curb, dtype: int64
#
# engineType
# False    222
# Name: engineType, dtype: int64
#
# Cylinders
# False    222
# Name: Cylinders, dtype: int64
#
# engineSize
# False    222
# Name: engineSize, dtype: int64
#
# system
# False    222
# Name: system, dtype: int64
#
# bore
# False    222
# Name: bore, dtype: int64
#
# stroke
# False    222
# Name: stroke, dtype: int64
#
# compression
# False    222
# Name: compression, dtype: int64
#
# horsepower
# False    222
# Name: horsepower, dtype: int64
#
# peak
# False    222
# Name: peak, dtype: int64
#
# City
# False    222
# Name: City, dtype: int64
#
# Higway
# False    222
# Name: Higway, dtype: int64
#
# price
# False    222
# Name: price, dtype: int64
#
# City L/100km
# False    222
# Name: City L/100km, dtype: int64
#
# Higway L/100km
# False    222
# Name: Higway L/100km, dtype: int64

# %% [markdown]
# <h2 style="color: #2082d8"> 3 Estandarizacion de los datos </h2>
#
# <p> Que se hace en este apartado? </p>
#
# <ol>
#     <li>Se verifica el dominio de la variable y se ajusta, si es necesario</li>
#     <li>Se convierten los valores en funcion de su interpretacion</li>
#     <li>Se normalizan los datos para que los valores distintos queden entre 0 y 1</li>
#     <li>Binning</li>
# </ol>

# %% [markdown]
# <h2 style="color: #B22222""> 3 Estandarizacion de los datos</h2>
#
# <p>Que se hace en este apartado? </p>
#
# <ol>
#     <li>Se verifica el dominio de la variable y se ajusta, si es necesario</li>
#     <li>Se convierten los valores en funcion de su interpretacion</li>
#     <li>Se normalizan los datos para que los valores distintos queden entre 0 y 1</li>
#     <li>Binning</li>
# </ol>
#
# <h2 style="color: #2082d8"> 3.1 Verificacion del dominio de variables</h2>

# %%
dfAutos.head(5)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
# 2          1         122  alfa-romero  gas        std   two    hatchback
# 3          2         164         audi  gas        std  four        sedan
# 4          2         164         audi  gas        std  four        sedan
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower    peak  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0       111.0  5000.0
# 1    rwd  front  88.6  ...  3.47    2.68          9.0       111.0  5000.0
# 2    rwd  front  94.5  ...  2.68    3.47          9.0       154.0  5000.0
# 3    fwd  front  99.8  ...  3.19    3.40         10.0       102.0  5500.0
# 4    4wd  front  99.4  ...  3.19    3.40          8.0       115.0  5500.0
#
#   City  Higway    price  City L/100km  Higway L/100km
# 0   21      27  13495.0     11.190476        8.703704
# 1   21      27  16500.0     11.190476        8.703704
# 2   19      26  16500.0     12.368421        9.038462
# 3   24      30  13950.0      9.791667        7.833333
# 4   18      22  17450.0     13.055556       10.681818
#
# [5 rows x 28 columns]

# %%
dfAutos.dtypes
# Out:
# symboling           int64
# normalized          int32
# make               object
# fuel               object
# aspiration         object
# doors              object
# style              object
# wheels             object
# engine             object
# base              float64
# length            float64
# width             float64
# heingt            float64
# curb                int64
# engineType         object
# Cylinders          object
# engineSize          int64
# system             object
# bore              float64
# stroke            float64
# compression       float64
# horsepower        float64
# peak              float64
# City                int64
# Higway              int64
# price             float64
# City L/100km      float64
# Higway L/100km    float64
# dtype: object

# %%
dfAutos[["normalized"]] = dfAutos[["normalized"]].astype("int")
dfAutos[["bore", "stroke", "peak", "horsepower", "price"]] = dfAutos[["bore", "stroke", "peak", "horsepower", "price"]].astype("float")

# %%
dfAutos.dtypes
# Out:
# symboling           int64
# normalized          int32
# make               object
# fuel               object
# aspiration         object
# doors              object
# style              object
# wheels             object
# engine             object
# base              float64
# length            float64
# width             float64
# heingt            float64
# curb                int64
# engineType         object
# Cylinders          object
# engineSize          int64
# system             object
# bore              float64
# stroke            float64
# compression       float64
# horsepower        float64
# peak              float64
# City                int64
# Higway              int64
# price             float64
# City L/100km      float64
# Higway L/100km    float64
# dtype: object

# %% [markdown]
# <h3 style="color: #B22222">3.2 Estandarizacion de valores</h3>

# %%
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
#
#    Higway  price City L/100km Higway L/100km
# 0      27  13495    11.190476       8.703704
# 1      27  16500    11.190476       8.703704
# 2      26  16500    12.368421       9.038462
#
# [3 rows x 28 columns]

# %%
dfAutos["City L/100km"] = 235/dfAutos["City"]
dfAutos["Higway L/100km"] = 235/dfAutos["Higway"]
dfAutos.head(3)
# Out:
#    symboling normalized         make fuel aspiration doors        style  \
# 0          3        122  alfa-romero  gas        std   two  convertible
# 1          3        122  alfa-romero  gas        std   two  convertible
# 2          1        122  alfa-romero  gas        std   two    hatchback
#
#   wheels engine  base  ...  bore  stroke  compression  horsepower  peak City  \
# 0    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 1    rwd  front  88.6  ...  3.47    2.68          9.0         111  5000   21
# 2    rwd  front  94.5  ...  2.68    3.47          9.0         154  5000   19
#
#    Higway  price City L/100km Higway L/100km
# 0      27  13495    11.190476       8.703704
# 1      27  16500    11.190476       8.703704
# 2      26  16500    12.368421       9.038462
#
# [3 rows x 28 columns]

# %% [markdown]
# <h3 style="color: #B22222">3.3 Normalizacion de datos</h3>

# %%
dfTemp = dfAutos[["length", "width", "heingt"]]
dfTemp.head(5)
# Out:
#      length     width    heingt
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %%
dfAutos["length"] = dfAutos["length"]/dfAutos["length"].max()
dfAutos["width"] = dfAutos["width"]/dfAutos["width"].max()
dfAutos["heingt"] = dfAutos["heingt"]/dfAutos["heingt"].max()

# %%
dfTemp2 = dfAutos[["length","width","heingt"]]
dfTemp2.head(5)
# Out:
#      length     width    heingt
# 0  0.811148  0.890278  0.816054
# 1  0.811148  0.890278  0.816054
# 2  0.822681  0.909722  0.876254
# 3  0.848630  0.919444  0.908027
# 4  0.848630  0.922222  0.908027

# %% [markdown]
# <h3 style="color: #B22222">3.4 Binning</h3>

# %%
dfTemp = dfAutos["horsepower"]
dfTemp.head(10)
# Out:
# 0    111
# 1    111
# 2    154
# 3    102
# 4    115
# 5    110
# 6    110
# 7    110
# 8    140
# 9    101
# Name: horsepower, dtype: object

# %%
dfAutos.dtypes
# Out:
# symboling           int64
# normalized         object
# make               object
# fuel               object
# aspiration         object
# doors              object
# style              object
# wheels             object
# engine             object
# base              float64
# length            float64
# width             float64
# heingt            float64
# curb                int64
# engineType         object
# Cylinders          object
# engineSize          int64
# system             object
# bore               object
# stroke             object
# compression       float64
# horsepower         object
# peak               object
# City                int64
# Higway              int64
# price              object
# City L/100km      float64
# Higway L/100km    float64
# dtype: object

# %%
bins = np.linspace(min(dfAutos["horsepower"]), max(dfAutos["horsepower"]), 4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
groupNames = ["Bajo", "Medio", "Alto"]
dfAutos["horsepowerBins"] = pd.cut(dfAutos["horsepower"], bins, labels=groupNames, include_lowest=True)
dfAutos[["horsepower","horsepowerBins"]].head(5)
# Out:
#    horsepower horsepowerBins
# 0       111.0           Bajo
# 1       111.0           Bajo
# 2       154.0          Medio
# 3       102.0           Bajo
# 4       115.0           Bajo

# %%
dfAutos["horsepowerBins"].value_counts()
# Out:
# Bajo     174
# Medio     43
# Alto       5
# Name: horsepowerBins, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

plt.pyplot.hist(dfAutos["horsepower"])

plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("horsepower")
# Out:
# Text(0.5, 1.0, 'horsepower')

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

plt.pyplot.hist(dfAutos["horsepowerBins"])

plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("cantidad")
plt.pyplot.title("horsepower")
# Out:
# Text(0.5, 1.0, 'horsepower')

# %%
dfAutos.head(2)
# Out:
#    symboling  normalized         make fuel aspiration doors        style  \
# 0          3         122  alfa-romero  gas        std   two  convertible
# 1          3         122  alfa-romero  gas        std   two  convertible
#
#   wheels engine  base  ...  stroke  compression  horsepower    peak City  \
# 0    rwd  front  88.6  ...    2.68          9.0       111.0  5000.0   21
# 1    rwd  front  88.6  ...    2.68          9.0       111.0  5000.0   21
#
#   Higway    price City L/100km  Higway L/100km  horsepowerBins
# 0     27  13495.0    11.190476        8.703704            Bajo
# 1     27  16500.0    11.190476        8.703704            Bajo
#
# [2 rows x 29 columns]
